# %%
# %load_ext autoreload
# %autoreload 2

# %%
import smart_open

# %%
with smart_open.open("./influence.jsonl.gz") as infile:
    for line in infile:
        print(line)
        break
# Out:
# {"creator": ["Edward Hall"], "datePublished": "2018-04-01", "docSubType": "book-review", "docType": "article", "id": "http://www.jstor.org/stable/26419472", "identifier": [{"name": "issn", "value": "00905917"}, {"name": "oclc", "value": "48534438"}, {"name": "lccn", "value": "2001-227383"}, {"name": "local_uuid", "value": "d32e9a86-2aee-3d4d-93ed-d9ce5fb03318"}, {"name": "local_doi", "value": "10.2307/26419472"}, {"name": "journal_id", "value": "politicaltheory"}], "isPartOf": "Political Theory", "issueNumber": "2", "language": ["eng"], "outputFormat": ["unigram", "bigram", "trigram"], "pageCount": 6, "pageEnd": "327", "pageStart": "322", "pagination": "pp. 322-327", "provider": "jstor", "publicationYear": 2018, "publisher": "Sage Publications, Inc.", "sourceCategory": ["Political Science", "Social Sciences", "Philosophy", "Humanities"], "tdmCategory": ["Philosophy - Epistemology"], "title": "Review Article", "url": "http://www.jstor.org/stable/26419472", "volumeNumber": "46", "wordC
# ...
