# %%
from collections import Counter
import json

import nltk
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from ctfidf import CTFIDFVectorizer

# %%
stopwords_en = nltk.corpus.stopwords.words('english')
#stopwords_en
stopwords_custom = ["mr","ms","mrs","said"]
stopwords_en = stopwords_en + stopwords_custom

# %%
api_url = "https://api.nytimes.com/svc/archive/v1/2022/5.json?api-key=[YOUR_API_KEY]"

# %%
def get_argmax(row):
    max_count = 0
    argmax = None
    #print(row)
    for row_key, row_val in row.iteritems():
        if row_val > max_count:
            max_count = row_val
            argmax = row_key
    return argmax

# %% [markdown]
# ### Load data

# %%
json_fpath = "./nyt_2022-05.json"

# %%
with open(json_fpath, 'r', encoding='utf-8') as infile:
    nyt_data = json.load(infile)

# %%
nyt_data['response'].keys()
# Out:
# dict_keys(['docs', 'meta'])

# %%
docs = nyt_data['response']['docs']

# %%
docs[0]['snippet']
# Out:
# 'A police chief said that victims’ bodies were discovered in a forest, and showed signs of mutilation.'

# %%
docs[0]['lead_paragraph']
# Out:
# 'The bodies of three men were found in a pit near Bucha, a few miles west of Kyiv, Ukraine’s capital, with signs that the civilians had been “tortured to death” by Russian troops, the regional police chief said on Saturday.'

# %%
docs[0]['section_name']
# Out:
# 'World'

# %%
doc_data = [(doc['section_name'], doc['snippet'] + " " + doc['lead_paragraph']) for doc in docs]

# %%
doc_data[:5]
# Out:
# [('World',
#   'A police chief said that victims’ bodies were discovered in a forest, and showed signs of mutilation. The bodies of three men were found in a pit near Bucha, a few miles west of Kyiv, Ukraine’s capital, with signs that the civilians had been “tortured to death” by Russian troops, the regional police chief said on Saturday.'),
#  ('Homepage',
#   'The war’s worst atrocities have been discovered in this little Ukrainian town not far from the capital of Kyiv. The war’s worst atrocities have been discovered in this little Ukrainian town not far from the capital of Kyiv.'),
#  ('Sports',
#   'Paul Salata made a point of celebrating the last player selected in the draft. His family carried on the tradition by honoring the 262nd pick on Saturday. LAS VEGAS — Only the hardiest of N.F.L. fans stick around to watch the end of the third and final day of the draft. To Paul Salata, it was pure joy.'),
#  ('Sports',
#   'The search for elite players is so competitive that IMG, the agency that once ruled tennis, is cultivating preteens to find the next prodigy, giving them access to representatives from the pro tours and Nike. ACHARNES, Greece — Behold Dominik Defoe. Ten years old and barely taller than the net. Golden brown shoulder-length curls bouncing in the air as he chases and crushes tennis balls, which he does better than just about any kid his age.'),
#  ('Arts',
#   'The soprano Liudmyla Monastyrska, replacing the Russian superstar Anna Netrebko at the Met in “Turandot,” wrapped herself in a Ukrainian flag for her curtain call. Liudmyla Monastyrska, the Ukrainian soprano, sang the title role in “Turandot” at the Metropolitan Opera on Saturday night in place of the Russian diva Anna Netrebko, whom the company dropped over her past support of President Vladimir V. Putin of Russia.')]

# %%
# assign a number to each section
section_counts = Counter([d[0] for d in doc_data])

# %%
sorted(section_counts.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('U.S.', 849),
#  ('World', 466),
#  ('Opinion', 316),
#  ('Arts', 300),
#  ('Business Day', 291),
#  ('Sports', 223),
#  ('New York', 193),
#  ('Books', 164),
#  ('Briefing', 136),
#  ('Style', 128),
#  ('Movies', 119),
#  ('The Learning Network', 114),
#  ('Food', 112),
#  ('Real Estate', 100),
#  ('Crosswords & Games', 74),
#  ('Theater', 72),
#  ('Technology', 63),
#  ('Science', 55),
#  ('Well', 48),
#  ('Podcasts', 46),
#  ('Magazine', 43),
#  ('Health', 42),
#  ('Climate', 37),
#  ('Today’s Paper', 31),
#  ('Corrections', 30),
#  ('Travel', 30),
#  ('T Magazine', 27),
#  ('Times Insider', 13),
#  ('The Upshot', 9),
#  ('Your Money', 8),
#  ('Fashion & Style', 8),
#  ('Reader Center', 6),
#  ('Headway', 5),
#  ('Smarter Living', 4),
#  ('Obituaries', 4),
#  ('Special Series', 3),
#  ('en Español', 3),
#  ('Homepage', 2),
#  ('Burst', 2),
#  ('T Brand', 1),
#  ('The New York Times Presents', 1),
#  ('International Home', 1)]

# %% [markdown]
# ### Choose relevant sections

# %%
# Keep only the most relevant sections
key_sections = [
    "U.S.","World","Arts","Business Day","Sports",
    "Books","Movies","Food","Real Estate","Technology"
]
classnum_to_sec = {i: key_sections[i] for i in range(len(key_sections))}

# %%
key_data = [d for d in doc_data if d[0] in key_sections]

# %%
# Also filter too-short articles
key_data = [d for d in key_data if len(d[1]) > 20]
#len(key_data)

# %%
# And assign numbers
data_rows = [{'section': d[0], 'text_raw': d[1], 'sec_num': key_sections.index(d[0])} for d in key_data]

# %%
data_df = pd.DataFrame(data_rows)
#data_df

# %% [markdown]
# ### Cleaning

# %%
punct_list = '“.’”,—()'
def remove_punct(text):
    # Special case for "-", we replace it with a space
    clean_chars = [c.replace("-"," ") for c in text if c not in punct_list]
    return "".join(clean_chars)

# %%
plural_map = {
    "presidents": "president",
    "wars": "war",
    "games": "game", "leagues": "league", "teams": "team",
    "books": "book",
    "films": "film",
    "restaurants": "restaurant",
    "homes": "home",
    "house": "home",
    "apartments": "apartment",
    "countries": "country", "countrys": "country",
    "companies": "company", "companys": "company",
    "fashionable": "fashion",
    "states": "state",
    "republicans": "republican",
    "readers": "read", "reading": "read",
    "senators": "senator",
}
def map_plurals(text):
    text_tokens = text.split()
    clean_tokens = [(plural_map[t] if t in plural_map else t) for t in text_tokens]
    return " ".join(clean_tokens)

# %%
def remove_stopwords(text):
    text_tokens = text.split()
    clean_tokens = [t for t in text_tokens if t not in stopwords_en]
    return " ".join(clean_tokens)

# %%
def preprocess_corpus(data_df):
    data_df['text'] = data_df['text_raw'].str.lower()
    data_df['text'] = data_df['text'].apply(remove_punct)
    data_df['text'] = data_df['text'].apply(remove_stopwords)
    data_df['text'] = data_df['text'].apply(map_plurals)

# %% [markdown]
# ### Now cTFIDF

# %%
def compute_ctfidf(data_df, classnum_to_sec):
    doc_class_df = data_df.groupby(['sec_num'], as_index=False).agg({'text': ' '.join})
    # Create bag of words
    ngrams = 1
    #min_df = 0.4
    #min_df = 0.24
    min_df = 0.1
    count_vectorizer = CountVectorizer(ngram_range=(1,ngrams), min_df=min_df)
    #count_vectorizer = CountVectorizer(ngram_range=(1,ngrams))
    count_vectorizer = count_vectorizer.fit(doc_class_df['text'])
    count = count_vectorizer.transform(doc_class_df['text'])
    words = count_vectorizer.get_feature_names_out()
    # Extract top 10 words
    ctfidf = CTFIDFVectorizer().fit_transform(count, n_samples=len(data_df)).toarray()
    num_top_words = 50
    words_per_class = {classnum_to_sec[label]: list(reversed([words[index] for index in ctfidf[label].argsort()[-num_top_words:]]))
                       for label in doc_class_df['sec_num']}
    return words_per_class

# %%
data_df
# Out:
#      section                                           text_raw  sec_num
# 0      World  A police chief said that victims’ bodies were ...        1
# 1     Sports  Paul Salata made a point of celebrating the la...        4
# 2     Sports  The search for elite players is so competitive...        4
# 3       Arts  The soprano Liudmyla Monastyrska, replacing th...        2
# 4       U.S.  Amid concerns about Covid, President Biden off...        0
# ...      ...                                                ...      ...
# 2682    Arts  The Ukrainian city’s distinctive architecture ...        2
# 2683  Sports  Zverev will face either Rafael Nadal or Novak ...        4
# 2684   Books  Tom Perrotta’s sequel to “Election” finds Flic...        5
# 2685    Arts  The company’s spring season, a double whammy o...        2
# 2686    U.S.  Some European officials want to use more than ...        0
#
# [2687 rows x 3 columns]

# %%
words_per_class = compute_ctfidf(data_df, classnum_to_sec)
words_per_class
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 words_per_class = compute_ctfidf(data_df, classnum_to_sec)
#       2 words_per_class
#
# Input In [25], in compute_ctfidf(data_df, classnum_to_sec)
#       1 def compute_ctfidf(data_df, classnum_to_sec):
# ----> 2     doc_class_df = data_df.groupby(['sec_num'], as_index=False).agg({'text': ' '.join})
#       3     # Create bag of words
#       4     ngrams = 1
#
# File ~\lib\site-packages\pandas\core\groupby\generic.py:869, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     866 func = maybe_mangle_lambdas(func)
#     868 op = GroupByApply(self, func, args, kwargs)
# --> 869 result = op.agg()
#     870 if not is_dict_like(func) and result is not None:
#     871     return result
#
# File ~\lib\site-packages\pandas\core\apply.py:168, in Apply.agg(self)
#     165     return self.apply_str()
#     167 if is_dict_like(arg):
# --> 168     return self.agg_dict_like()
#     169 elif is_list_like(arg):
#     170     # we require a list, but not a 'str'
#     171     return self.agg_list_like()
#
# File ~\lib\site-packages\pandas\core\apply.py:467, in Apply.agg_dict_like(self)
#     464     selected_obj = obj._selected_obj
#     465     selection = obj._selection
# --> 467 arg = self.normalize_dictlike_arg("agg", selected_obj, arg)
#     469 if selected_obj.ndim == 1:
#     470     # key only used for output
#     471     colg = obj._gotitem(selection, ndim=1)
#
# File ~\lib\site-packages\pandas\core\apply.py:585, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     583     if len(cols) > 0:
#     584         cols_sorted = list(safe_sort(list(cols)))
# --> 585         raise KeyError(f"Column(s) {cols_sorted} do not exist")
#     587 is_aggregator = lambda x: isinstance(x, (list, tuple, dict))
#     589 # if we have a dict of any non-scalars
#     590 # eg. {'A' : ['mean']}, normalize all to
#     591 # be list-likes
#     592 # Cannot use func.values() because arg may be a Series
#
# KeyError: "Column(s) ['text'] do not exist"

# %% [markdown]
# ### cTFIDF Results

# %%
def print_ctfidf(words_per_class):
    for cur_class in words_per_class.keys():
        print(f"=====[ {cur_class} ]=====")
        cur_class_words = words_per_class[cur_class]
        #print(cur_class_words)
        #print([w for w in cur_class_words if w.endswith("s")])
        print([w for w in cur_class_words])
        #joblib.dump(cur_class_words, f"./indic_words/{cur_class}.pkl")
print_ctfidf(words_per_class)
# Out:
# =====[ Sports ]=====
# ['game', 'said', 'team', 'season', 'first', 'coach', 'last', 'year', 'one', 'would', 'play', 'two', 'players', 'league', 'points', 'time', 'three', 'football', 'like', 'back', 'we', 'giants', 'he', 'new', 'could', 'it', 'bowl', 'get', 'going', 'second', 'years', 'state', 'left', 'player', 'field', 'made', 'that', 'patriots', 'manning', 'good', 'knicks', 'colts', '10', 'think', 'night', 'quarterback', 'point', 'four', 'way', 'victory']
# =====[ Arts ]=====
# ['new', 'music', 'show', 'like', 'one', 'art', 'pm', 'said', 'work', 'two', 'the', 'first', 'york', 'also', 'museum', 'series', 'american', 'time', 'made', 'would', 'dance', 'years', 'songs', 'well', 'million', 'theater', 'film', 'works', 'life', 'street', 'ballet', 'last', 'way', 'company', 'album', 'three', 'year', 'band', 'night', 'much', 'west', '10', 'it', 'orchestra', 'played', 'even', 'review', 'performance', 'another', 'world']
# =====[ U.S. ]=====
# ['said', 'new', 'state', 'would', 'people', 'one', 'court', 'case', 'home', 'city', 'years', 'federal', 'two', 'clinton', 'say', 'last', 'republican', 'also', 'year', 'president', 'many', 'officials', 'government', 'could', 'we', 'like', '21', 'department', 'public', 'first', 'law', 'senator', 'time', 'it', 'bush', 'former', 'police', 'washington', 'company', 'democrats', '20', 'justice', 'united', 'three', 'percent', 'the', 'york', 'since', 'judge', 'lawyers']
# =====[ World ]=====
# ['said', 'government', 'country', 'would', 'minister', 'officials', 'police', 'people', 'one', 'president', 'state', 'united', 'also', 'political', 'two', 'last', 'many', 'year', 'military', 'war', 'new', 'security', 'prime', 'party', 'russia', 'years', 'palestinian', 'nations', 'could', 'say', 'hamas', 'we', 'american', 'israeli', 'forces', 'friday', 'since', 'iraq', 'general', 'home', 'killed', 'oil', 'foreign', 'news', 'city', 'former', 'group', 'leaders', 'iran', 'israel']
# =====[ Real Estate ]=====
# ['number', 'home', 'bathrooms', 'said', 'building', 'apartment', 'weeks', 'market', 'bedrooms', 'million', 'taxes', 'full', 'new', 'half', 'listed', 'two', 'square', 'bedroom', 'room', 'one', 'broker', 'year', 'street', 'old', 'brokers', 'lot', 'estate', 'floors', 'kitchen', 'op', 'floor', 'co', 'property', 'foot', 'garage', 'acre', 'real', 'family', 'living', 'like', 'city', 'avenue', 'would', 'also', 'ft', 'fireplace', 'buildings', 'car', 'park', 'three']

# %% [markdown]
# ### Define Keywords

# %%
keywords = {
    #"U.S." : ["washington", "state", "republican"],
    #"U.S.": ["court","federal","state"],
    "U.S.": ["president","court","republican"],
    #"World": ["war", "country", "military"],
    "World": ["government","country","officials"],
    "Arts": ["music", "art", "artist"],
    "Business Day": ["economy", "investors", "inflation"],
    "Sports": ["game", "league", "team"],
    "Books": ["book", "novel", "read"],
    #"Style": ["fashion", "brand"],
    "Movies": ["film", "movie", "director"],
    "Food": ["restaurant", "food", "kitchen"],
    "Real Estate": ["home", "apartment", "available"],
    "Technology": ["digital", "online", "tech"],
}

# %%
# Get keywords in LaTeX form
for cur_section, cur_kw_list in keywords.items():
    tex_list = ["\\texttt{" + kw + "}" for kw in cur_kw_list]
    kw_str = ", ".join(tex_list)
    print(f"{cur_section} & {kw_str} \\\\")
# Out:
# U.S. & \texttt{president}, \texttt{court}, \texttt{republican} \\
# World & \texttt{government}, \texttt{country}, \texttt{officials} \\
# Arts & \texttt{music}, \texttt{art}, \texttt{artist} \\
# Business Day & \texttt{economy}, \texttt{investors}, \texttt{inflation} \\
# Sports & \texttt{game}, \texttt{league}, \texttt{team} \\
# Books & \texttt{book}, \texttt{novel}, \texttt{read} \\
# Movies & \texttt{film}, \texttt{movie}, \texttt{director} \\
# Food & \texttt{restaurant}, \texttt{food}, \texttt{kitchen} \\
# Real Estate & \texttt{home}, \texttt{apartment}, \texttt{available} \\
# Technology & \texttt{digital}, \texttt{online}, \texttt{tech} \\

# %%
data_df['text_tokens'] = data_df['text'].str.split()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [1694], in <cell line: 1>()
# ----> 1 data_df['text_tokens'] = data_df['text'].str.split()
#
# File ~\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'text'

# %%
data_df
# Out:
#      section                                           text_raw  sec_num
# 0      World  A police chief said that victims’ bodies were ...        1
# 1     Sports  Paul Salata made a point of celebrating the la...        4
# 2     Sports  The search for elite players is so competitive...        4
# 3       Arts  The soprano Liudmyla Monastyrska, replacing th...        2
# 4       U.S.  Amid concerns about Covid, President Biden off...        0
# ...      ...                                                ...      ...
# 2682    Arts  The Ukrainian city’s distinctive architecture ...        2
# 2683  Sports  Zverev will face either Rafael Nadal or Novak ...        4
# 2684   Books  Tom Perrotta’s sequel to “Election” finds Flic...        5
# 2685    Arts  The company’s spring season, a double whammy o...        2
# 2686    U.S.  Some European officials want to use more than ...        0
#
# [2687 rows x 3 columns]

# %%
def get_token_counts(token_list, section):
    section_keywords = keywords[section]
    total_count = 0
    for cur_sec_kw in section_keywords:
        total_count += token_list.count(cur_sec_kw)
    return total_count

# %%
for section, sec_keywords in keywords.items():
    get_counts_partial = lambda token_list: get_token_counts(token_list, section)
    data_df[section] = data_df['text_tokens'].apply(get_counts_partial)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text_tokens'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [1697], in <cell line: 1>()
#       1 for section, sec_keywords in keywords.items():
#       2     get_counts_partial = lambda token_list: get_token_counts(token_list, section)
# ----> 3     data_df[section] = data_df['text_tokens'].apply(get_counts_partial)
#
# File ~\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'text_tokens'

# %%
data_df
# Out:
#      section                                           text_raw  sec_num
# 0      World  A police chief said that victims’ bodies were ...        1
# 1     Sports  Paul Salata made a point of celebrating the la...        4
# 2     Sports  The search for elite players is so competitive...        4
# 3       Arts  The soprano Liudmyla Monastyrska, replacing th...        2
# 4       U.S.  Amid concerns about Covid, President Biden off...        0
# ...      ...                                                ...      ...
# 2682    Arts  The Ukrainian city’s distinctive architecture ...        2
# 2683  Sports  Zverev will face either Rafael Nadal or Novak ...        4
# 2684   Books  Tom Perrotta’s sequel to “Election” finds Flic...        5
# 2685    Arts  The company’s spring season, a double whammy o...        2
# 2686    U.S.  Some European officials want to use more than ...        0
#
# [2687 rows x 3 columns]

# %%
cols_to_keep = ["section","text"] + key_sections
data_df[:5][cols_to_keep]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [1699], in <cell line: 2>()
#       1 cols_to_keep = ["section","text"] + key_sections
# ----> 2 data_df[:5][cols_to_keep]
#
# File ~\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~\lib\site-packages\pandas\core\indexes\base.py:5845, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['text', 'U.S.', 'World', 'Arts', 'Business Day', 'Sports', 'Books', 'Movies', 'Food', 'Real Estate', 'Technology'] not in index"

# %%
data_df['predicted'] = data_df[key_sections].apply(get_argmax, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [1700], in <cell line: 1>()
# ----> 1 data_df['predicted'] = data_df[key_sections].apply(get_argmax, axis=1)
#
# File ~\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~\lib\site-packages\pandas\core\indexes\base.py:5842, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5840     if use_interval_msg:
#    5841         key = list(key)
# -> 5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['U.S.', 'World', 'Arts', 'Business Day', 'Sports', 'Books', 'Movies',\n       'Food', 'Real Estate', 'Technology'],\n      dtype='object')] are in the [columns]"

# %%
data_df
# Out:
#      section                                           text_raw  sec_num
# 0      World  A police chief said that victims’ bodies were ...        1
# 1     Sports  Paul Salata made a point of celebrating the la...        4
# 2     Sports  The search for elite players is so competitive...        4
# 3       Arts  The soprano Liudmyla Monastyrska, replacing th...        2
# 4       U.S.  Amid concerns about Covid, President Biden off...        0
# ...      ...                                                ...      ...
# 2682    Arts  The Ukrainian city’s distinctive architecture ...        2
# 2683  Sports  Zverev will face either Rafael Nadal or Novak ...        4
# 2684   Books  Tom Perrotta’s sequel to “Election” finds Flic...        5
# 2685    Arts  The company’s spring season, a double whammy o...        2
# 2686    U.S.  Some European officials want to use more than ...        0
#
# [2687 rows x 3 columns]

# %%
data_df['section'].value_counts()
# Out:
# U.S.            849
# World           466
# Arts            300
# Business Day    291
# Sports          223
# Books           164
# Movies          119
# Food            112
# Real Estate     100
# Technology       63
# Name: section, dtype: int64

# %%
predict_df = data_df[~pd.isna(data_df['predicted'])].copy()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'predicted'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [1703], in <cell line: 1>()
# ----> 1 predict_df = data_df[~pd.isna(data_df['predicted'])].copy()
#
# File ~\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'predicted'

# %%
predict_df
# Out:
#                      id sections  \
# 4     01/22/1820684.xml   Sports
# 5     01/22/1820655.xml     Arts
# 7     01/22/1820683.xml    World
# 9     01/22/1820743.xml   Sports
# 12    01/22/1820744.xml     U.S.
# ...                 ...      ...
# 5600  01/18/1819742.xml   Sports
# 5601  01/18/1819730.xml   Sports
# 5610  01/18/1819595.xml     Arts
# 5616  01/18/1819745.xml   Sports
# 5618  01/18/1819613.xml     U.S.
#
#                                                text_raw  num_sections  \
# 4     Marquette point guard Dominic James wore dark ...             1
# 5     Even in their absence, the Grateful Dead can p...             1
# 7     A damaged and listing cargo ship was spilling ...             1
# 9     As Chicago Bears defensive end Adewale Ogunley...             1
# 12    Nine years after he began serving a life sente...             1
# ...                                                 ...           ...
# 5600  It is halfway through the season, and just the...             1
# 5601  The telephone calls keep coming, so Mets Gener...             1
# 5610  Stravinsky was arguably the most important com...             1
# 5616  Casey Powell made a big mistake bringing his w...             1
# 5618  A Mexican immigrant was shot and killed on Fri...             1
#
#       sec_num                                               text  \
# 4           0  marquette point guard dominic james wore dark ...
# 5           1  even absence grateful dead pack hall saturday ...
# 7           3  damaged listing cargo ship spilling fuel cargo...
# 9           0  chicago bears defensive end adewale ogunleye w...
# 12          2  nine years began serving life sentence unabomb...
# ...       ...                                                ...
# 5600        0  halfway season right time struggling team rein...
# 5601        0  telephone calls keep coming mets general manag...
# 5610        1  stravinsky arguably important composer dance 2...
# 5616        0  casey powell made big mistake bringing wife ne...
# 5618        2  mexican immigrant shot killed friday border pa...
#
#                                             text_tokens  U.S.  World  Arts  \
# 4     [marquette, point, guard, dominic, james, wore...     0      1     0
# 5     [even, absence, grateful, dead, pack, hall, sa...     0      1     2
# 7     [damaged, listing, cargo, ship, spilling, fuel...     0      5     0
# 9     [chicago, bears, defensive, end, adewale, ogun...     0      0     0
# 12    [nine, years, began, serving, life, sentence, ...    14     11     0
# ...                                                 ...   ...    ...   ...
# 5600  [halfway, season, right, time, struggling, tea...     4      0     0
# 5601  [telephone, calls, keep, coming, mets, general...     0      1     0
# 5610  [stravinsky, arguably, important, composer, da...     3      0     3
# 5616  [casey, powell, made, big, mistake, bringing, ...     0      0     0
# 5618  [mexican, immigrant, shot, killed, friday, bor...     4      2     0
#
#       Business Day  Sports  Books  Movies  Food  Real Estate  Technology  \
# 4                0      14      0       0     0            3           0
# 5                0       0      0       0     0            0           0
# 7                0       1      0       0     0            0           0
# 9                0       3      0       0     0            0           0
# 12               0       0      2       0     0            2           0
# ...            ...     ...    ...     ...   ...          ...         ...
# 5600             0       7      0       0     0            0           0
# 5601             0       7      0       0     0            3           0
# 5610             0       0      0       0     0            0           0
# 5616             0      17      0       0     0            1           0
# 5618             0       0      0       0     0            1           0
#
#      predicted  correct
# 4       Sports     True
# 5         Arts     True
# 7        World     True
# 9       Sports     True
# 12        U.S.     True
# ...        ...      ...
# 5600    Sports     True
# 5601    Sports     True
# 5610      Arts     True
# 5616    Sports     True
# 5618      U.S.     True
#
# [1411 rows x 19 columns]

# %%
predict_df['correct'] = predict_df['section'] == predict_df['predicted']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'section'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [1705], in <cell line: 1>()
# ----> 1 predict_df['correct'] = predict_df['section'] == predict_df['predicted']
#
# File ~\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'section'

# %%
predict_df
# Out:
#                      id sections  \
# 4     01/22/1820684.xml   Sports
# 5     01/22/1820655.xml     Arts
# 7     01/22/1820683.xml    World
# 9     01/22/1820743.xml   Sports
# 12    01/22/1820744.xml     U.S.
# ...                 ...      ...
# 5600  01/18/1819742.xml   Sports
# 5601  01/18/1819730.xml   Sports
# 5610  01/18/1819595.xml     Arts
# 5616  01/18/1819745.xml   Sports
# 5618  01/18/1819613.xml     U.S.
#
#                                                text_raw  num_sections  \
# 4     Marquette point guard Dominic James wore dark ...             1
# 5     Even in their absence, the Grateful Dead can p...             1
# 7     A damaged and listing cargo ship was spilling ...             1
# 9     As Chicago Bears defensive end Adewale Ogunley...             1
# 12    Nine years after he began serving a life sente...             1
# ...                                                 ...           ...
# 5600  It is halfway through the season, and just the...             1
# 5601  The telephone calls keep coming, so Mets Gener...             1
# 5610  Stravinsky was arguably the most important com...             1
# 5616  Casey Powell made a big mistake bringing his w...             1
# 5618  A Mexican immigrant was shot and killed on Fri...             1
#
#       sec_num                                               text  \
# 4           0  marquette point guard dominic james wore dark ...
# 5           1  even absence grateful dead pack hall saturday ...
# 7           3  damaged listing cargo ship spilling fuel cargo...
# 9           0  chicago bears defensive end adewale ogunleye w...
# 12          2  nine years began serving life sentence unabomb...
# ...       ...                                                ...
# 5600        0  halfway season right time struggling team rein...
# 5601        0  telephone calls keep coming mets general manag...
# 5610        1  stravinsky arguably important composer dance 2...
# 5616        0  casey powell made big mistake bringing wife ne...
# 5618        2  mexican immigrant shot killed friday border pa...
#
#                                             text_tokens  U.S.  World  Arts  \
# 4     [marquette, point, guard, dominic, james, wore...     0      1     0
# 5     [even, absence, grateful, dead, pack, hall, sa...     0      1     2
# 7     [damaged, listing, cargo, ship, spilling, fuel...     0      5     0
# 9     [chicago, bears, defensive, end, adewale, ogun...     0      0     0
# 12    [nine, years, began, serving, life, sentence, ...    14     11     0
# ...                                                 ...   ...    ...   ...
# 5600  [halfway, season, right, time, struggling, tea...     4      0     0
# 5601  [telephone, calls, keep, coming, mets, general...     0      1     0
# 5610  [stravinsky, arguably, important, composer, da...     3      0     3
# 5616  [casey, powell, made, big, mistake, bringing, ...     0      0     0
# 5618  [mexican, immigrant, shot, killed, friday, bor...     4      2     0
#
#       Business Day  Sports  Books  Movies  Food  Real Estate  Technology  \
# 4                0      14      0       0     0            3           0
# 5                0       0      0       0     0            0           0
# 7                0       1      0       0     0            0           0
# 9                0       3      0       0     0            0           0
# 12               0       0      2       0     0            2           0
# ...            ...     ...    ...     ...   ...          ...         ...
# 5600             0       7      0       0     0            0           0
# 5601             0       7      0       0     0            3           0
# 5610             0       0      0       0     0            0           0
# 5616             0      17      0       0     0            1           0
# 5618             0       0      0       0     0            1           0
#
#      predicted  correct
# 4       Sports     True
# 5         Arts     True
# 7        World     True
# 9       Sports     True
# 12        U.S.     True
# ...        ...      ...
# 5600    Sports     True
# 5601    Sports     True
# 5610      Arts     True
# 5616    Sports     True
# 5618      U.S.     True
#
# [1411 rows x 19 columns]

# %%
correct_counts = predict_df['correct'].value_counts()

# %%
correct_counts
# Out:
# True     1050
# False     361
# Name: correct, dtype: int64

# %%
correct_counts[True] / (correct_counts[True]+correct_counts[False])
# Out:
# 0.744153082919915

# %%
pd.crosstab(predict_df['correct'], predict_df['section'], normalize="columns")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'section'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [1710], in <cell line: 1>()
# ----> 1 pd.crosstab(predict_df['correct'], predict_df['section'], normalize="columns")
#
# File ~\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'section'

# %% [markdown]
# ## Now the full articles (from the LDC corpus)

# %%
import glob
import os
import tarfile

import xmltodict

# %%
ldc_path = "./nyt_corpus/data/2007/"

# %%
os.listdir(ldc_path)
# Out:
# ['01', '01.tgz', '02.tgz', '03.tgz', '04.tgz', '05.tgz', '06.tgz']

# %%
ldc_fpath = os.path.join(ldc_path, "01.tgz")

# %%
tar = tarfile.open(ldc_fpath, "r:gz")

# %%
def parse_content(content):
    content_str = content.decode("utf-8")
    content_dict = xmltodict.parse(content_str)
    return content_dict['nitf']

# %%
def get_dict_item(item_list, key, val, other_key):
    # Helper fn
    results = [item for item in item_list if item[key] == val]
    if len(results) == 0:
        return ""
    return results[0][other_key]

# %%
content_rows = []
for member in tar.getmembers():
    #print(tar.getnames())
    f = tar.extractfile(member)
    if f is not None:
        #print(dir(member))
        print(member.name)
        content = f.read()
        content_dict = parse_content(content)
        sections = get_dict_item(content_dict['head']['meta'], "@name", "online_sections", "@content")
        if sections == "Paid Death Notices":
            continue
        if "Corrections" in sections:
            continue
        body_content = content_dict['body']['body.content']
# %%
art_df = pd.DataFrame(content_rows)

# %%
art_df['sections'] = art_df['sections'].str.replace("Front Page; ","")

# %%
art_df['num_sections'] = art_df['sections'].apply(lambda x: len(x.split(";")))

# %%
# Drop articles with multiple sections, for now
art_df = art_df[art_df['num_sections'] == 1].copy()

# %%
art_df['sections'].value_counts()
# Out:
# New York and Region    935
# Sports                 536
# Business               415
# Opinion                411
# Arts                   410
# U.S.                   259
# World                  248
# Style                  111
# Travel                  81
# Real Estate             76
# Health                  50
# Automobiles             46
# Magazine                34
# Week in Review          27
#                         22
# Job Market               2
# Theater                  1
# Front Page               1
# Technology               1
# Books                    1
# Name: sections, dtype: int64

# %%
sections_to_keep = [
    "Sports",
    #"Business",
    "Arts", "U.S.", "World", "Real Estate"
]
secnum_to_sec = {i: sections_to_keep[i] for i in range(len(sections_to_keep))}

# %%
art_df = art_df[art_df['sections'].isin(sections_to_keep)].copy()

# %%
art_df['sec_num'] = art_df['sections'].apply(lambda x: sections_to_keep.index(x))

# %%
art_df
# Out:
#                      id sections  \
# 4     01/22/1820684.xml   Sports
# 5     01/22/1820655.xml     Arts
# 7     01/22/1820683.xml    World
# 9     01/22/1820743.xml   Sports
# 12    01/22/1820744.xml     U.S.
# ...                 ...      ...
# 5601  01/18/1819730.xml   Sports
# 5610  01/18/1819595.xml     Arts
# 5615  01/18/1819592.xml     Arts
# 5616  01/18/1819745.xml   Sports
# 5618  01/18/1819613.xml     U.S.
#
#                                                text_raw  num_sections  sec_num
# 4     Marquette point guard Dominic James wore dark ...             1        0
# 5     Even in their absence, the Grateful Dead can p...             1        1
# 7     A damaged and listing cargo ship was spilling ...             1        3
# 9     As Chicago Bears defensive end Adewale Ogunley...             1        0
# 12    Nine years after he began serving a life sente...             1        2
# ...                                                 ...           ...      ...
# 5601  The telephone calls keep coming, so Mets Gener...             1        0
# 5610  Stravinsky was arguably the most important com...             1        1
# 5615  When is bridge like poker? When bluffing is in...             1        1
# 5616  Casey Powell made a big mistake bringing his w...             1        0
# 5618  A Mexican immigrant was shot and killed on Fri...             1        2
#
# [1529 rows x 5 columns]

# %%
preprocess_corpus(art_df)

# %% [markdown]
# ### cTFIDF

# %%
words_per_class = compute_ctfidf(art_df, secnum_to_sec)
#words_per_class

# %%
print_ctfidf(words_per_class)
# Out:
# =====[ Sports ]=====
# ['game', 'said', 'team', 'season', 'first', 'coach', 'last', 'year', 'one', 'would', 'play', 'two', 'players', 'league', 'points', 'time', 'three', 'football', 'like', 'back', 'we', 'giants', 'he', 'new', 'could', 'it', 'bowl', 'get', 'going', 'second', 'years', 'state', 'left', 'player', 'field', 'made', 'that', 'patriots', 'manning', 'good', 'knicks', 'colts', '10', 'think', 'night', 'quarterback', 'point', 'four', 'way', 'victory']
# =====[ Arts ]=====
# ['new', 'music', 'show', 'like', 'one', 'art', 'pm', 'said', 'work', 'two', 'the', 'first', 'york', 'also', 'museum', 'series', 'american', 'time', 'made', 'would', 'dance', 'years', 'songs', 'well', 'million', 'theater', 'film', 'works', 'life', 'street', 'ballet', 'last', 'way', 'company', 'album', 'three', 'year', 'band', 'night', 'much', 'west', '10', 'it', 'orchestra', 'played', 'even', 'review', 'performance', 'another', 'world']
# =====[ U.S. ]=====
# ['said', 'new', 'state', 'would', 'people', 'one', 'court', 'case', 'home', 'city', 'years', 'federal', 'two', 'clinton', 'say', 'last', 'republican', 'also', 'year', 'president', 'many', 'officials', 'government', 'senator', 'could', 'we', 'like', '21', 'department', 'public', 'first', 'law', 'time', 'it', 'bush', 'former', 'police', 'washington', 'company', 'democrats', '20', 'justice', 'united', 'three', 'percent', 'the', 'york', 'since', 'judge', 'lawyers']
# =====[ World ]=====
# ['said', 'government', 'country', 'would', 'minister', 'officials', 'police', 'people', 'one', 'president', 'state', 'united', 'also', 'political', 'two', 'last', 'many', 'year', 'military', 'war', 'new', 'security', 'prime', 'party', 'russia', 'years', 'palestinian', 'nations', 'could', 'say', 'hamas', 'we', 'american', 'israeli', 'forces', 'friday', 'since', 'iraq', 'general', 'home', 'killed', 'oil', 'foreign', 'news', 'city', 'former', 'group', 'leaders', 'iran', 'israel']
# =====[ Real Estate ]=====
# ['number', 'home', 'bathrooms', 'said', 'building', 'apartment', 'weeks', 'market', 'bedrooms', 'million', 'taxes', 'full', 'new', 'half', 'listed', 'two', 'square', 'bedroom', 'room', 'one', 'broker', 'year', 'street', 'old', 'brokers', 'lot', 'estate', 'floors', 'kitchen', 'op', 'floor', 'co', 'property', 'foot', 'garage', 'acre', 'real', 'family', 'living', 'like', 'city', 'avenue', 'would', 'also', 'ft', 'fireplace', 'buildings', 'car', 'park', 'three']

# %%
keywords_sub = {k: v for k, v in keywords.items() if k in sections_to_keep}

# %%
keywords_sub
# Out:
# {'U.S.': ['president', 'court', 'republican'],
#  'World': ['government', 'country', 'officials'],
#  'Arts': ['music', 'art', 'artist'],
#  'Sports': ['game', 'league', 'team'],
#  'Real Estate': ['home', 'apartment', 'available']}

# %%
art_df
# Out:
#                      id sections  \
# 4     01/22/1820684.xml   Sports
# 5     01/22/1820655.xml     Arts
# 7     01/22/1820683.xml    World
# 9     01/22/1820743.xml   Sports
# 12    01/22/1820744.xml     U.S.
# ...                 ...      ...
# 5601  01/18/1819730.xml   Sports
# 5610  01/18/1819595.xml     Arts
# 5615  01/18/1819592.xml     Arts
# 5616  01/18/1819745.xml   Sports
# 5618  01/18/1819613.xml     U.S.
#
#                                                text_raw  num_sections  \
# 4     Marquette point guard Dominic James wore dark ...             1
# 5     Even in their absence, the Grateful Dead can p...             1
# 7     A damaged and listing cargo ship was spilling ...             1
# 9     As Chicago Bears defensive end Adewale Ogunley...             1
# 12    Nine years after he began serving a life sente...             1
# ...                                                 ...           ...
# 5601  The telephone calls keep coming, so Mets Gener...             1
# 5610  Stravinsky was arguably the most important com...             1
# 5615  When is bridge like poker? When bluffing is in...             1
# 5616  Casey Powell made a big mistake bringing his w...             1
# 5618  A Mexican immigrant was shot and killed on Fri...             1
#
#       sec_num                                               text
# 4           0  marquette point guard dominic james wore dark ...
# 5           1  even absence grateful dead pack hall saturday ...
# 7           3  damaged listing cargo ship spilling fuel cargo...
# 9           0  chicago bears defensive end adewale ogunleye w...
# 12          2  nine years began serving life sentence unabomb...
# ...       ...                                                ...
# 5601        0  telephone calls keep coming mets general manag...
# 5610        1  stravinsky arguably important composer dance 2...
# 5615        1  bridge like poker? bluffing involved poker per...
# 5616        0  casey powell made big mistake bringing wife ne...
# 5618        2  mexican immigrant shot killed friday border pa...
#
# [1529 rows x 6 columns]

# %%
art_df['text_tokens'] = art_df['text'].str.split()

# %%
art_df
# Out:
#                      id sections  \
# 4     01/22/1820684.xml   Sports
# 5     01/22/1820655.xml     Arts
# 7     01/22/1820683.xml    World
# 9     01/22/1820743.xml   Sports
# 12    01/22/1820744.xml     U.S.
# ...                 ...      ...
# 5601  01/18/1819730.xml   Sports
# 5610  01/18/1819595.xml     Arts
# 5615  01/18/1819592.xml     Arts
# 5616  01/18/1819745.xml   Sports
# 5618  01/18/1819613.xml     U.S.
#
#                                                text_raw  num_sections  \
# 4     Marquette point guard Dominic James wore dark ...             1
# 5     Even in their absence, the Grateful Dead can p...             1
# 7     A damaged and listing cargo ship was spilling ...             1
# 9     As Chicago Bears defensive end Adewale Ogunley...             1
# 12    Nine years after he began serving a life sente...             1
# ...                                                 ...           ...
# 5601  The telephone calls keep coming, so Mets Gener...             1
# 5610  Stravinsky was arguably the most important com...             1
# 5615  When is bridge like poker? When bluffing is in...             1
# 5616  Casey Powell made a big mistake bringing his w...             1
# 5618  A Mexican immigrant was shot and killed on Fri...             1
#
#       sec_num                                               text  \
# 4           0  marquette point guard dominic james wore dark ...
# 5           1  even absence grateful dead pack hall saturday ...
# 7           3  damaged listing cargo ship spilling fuel cargo...
# 9           0  chicago bears defensive end adewale ogunleye w...
# 12          2  nine years began serving life sentence unabomb...
# ...       ...                                                ...
# 5601        0  telephone calls keep coming mets general manag...
# 5610        1  stravinsky arguably important composer dance 2...
# 5615        1  bridge like poker? bluffing involved poker per...
# 5616        0  casey powell made big mistake bringing wife ne...
# 5618        2  mexican immigrant shot killed friday border pa...
#
#                                             text_tokens
# 4     [marquette, point, guard, dominic, james, wore...
# 5     [even, absence, grateful, dead, pack, hall, sa...
# 7     [damaged, listing, cargo, ship, spilling, fuel...
# 9     [chicago, bears, defensive, end, adewale, ogun...
# 12    [nine, years, began, serving, life, sentence, ...
# ...                                                 ...
# 5601  [telephone, calls, keep, coming, mets, general...
# 5610  [stravinsky, arguably, important, composer, da...
# 5615  [bridge, like, poker?, bluffing, involved, pok...
# 5616  [casey, powell, made, big, mistake, bringing, ...
# 5618  [mexican, immigrant, shot, killed, friday, bor...
#
# [1529 rows x 7 columns]

# %%
for section, sec_keywords in keywords.items():
    get_counts_partial = lambda token_list: get_token_counts(token_list, section)
    art_df[section] = art_df['text_tokens'].apply(get_counts_partial)

# %%
art_df
# Out:
#                      id sections  \
# 4     01/22/1820684.xml   Sports
# 5     01/22/1820655.xml     Arts
# 7     01/22/1820683.xml    World
# 9     01/22/1820743.xml   Sports
# 12    01/22/1820744.xml     U.S.
# ...                 ...      ...
# 5601  01/18/1819730.xml   Sports
# 5610  01/18/1819595.xml     Arts
# 5615  01/18/1819592.xml     Arts
# 5616  01/18/1819745.xml   Sports
# 5618  01/18/1819613.xml     U.S.
#
#                                                text_raw  num_sections  \
# 4     Marquette point guard Dominic James wore dark ...             1
# 5     Even in their absence, the Grateful Dead can p...             1
# 7     A damaged and listing cargo ship was spilling ...             1
# 9     As Chicago Bears defensive end Adewale Ogunley...             1
# 12    Nine years after he began serving a life sente...             1
# ...                                                 ...           ...
# 5601  The telephone calls keep coming, so Mets Gener...             1
# 5610  Stravinsky was arguably the most important com...             1
# 5615  When is bridge like poker? When bluffing is in...             1
# 5616  Casey Powell made a big mistake bringing his w...             1
# 5618  A Mexican immigrant was shot and killed on Fri...             1
#
#       sec_num                                               text  \
# 4           0  marquette point guard dominic james wore dark ...
# 5           1  even absence grateful dead pack hall saturday ...
# 7           3  damaged listing cargo ship spilling fuel cargo...
# 9           0  chicago bears defensive end adewale ogunleye w...
# 12          2  nine years began serving life sentence unabomb...
# ...       ...                                                ...
# 5601        0  telephone calls keep coming mets general manag...
# 5610        1  stravinsky arguably important composer dance 2...
# 5615        1  bridge like poker? bluffing involved poker per...
# 5616        0  casey powell made big mistake bringing wife ne...
# 5618        2  mexican immigrant shot killed friday border pa...
#
#                                             text_tokens  U.S.  World  Arts  \
# 4     [marquette, point, guard, dominic, james, wore...     0      1     0
# 5     [even, absence, grateful, dead, pack, hall, sa...     0      1     2
# 7     [damaged, listing, cargo, ship, spilling, fuel...     0      5     0
# 9     [chicago, bears, defensive, end, adewale, ogun...     0      0     0
# 12    [nine, years, began, serving, life, sentence, ...    11     11     0
# ...                                                 ...   ...    ...   ...
# 5601  [telephone, calls, keep, coming, mets, general...     0      1     0
# 5610  [stravinsky, arguably, important, composer, da...     1      0     3
# 5615  [bridge, like, poker?, bluffing, involved, pok...     0      0     0
# 5616  [casey, powell, made, big, mistake, bringing, ...     1      0     0
# 5618  [mexican, immigrant, shot, killed, friday, bor...     2      2     0
#
#       Business Day  Sports  Books  Movies  Food  Real Estate  Technology
# 4                0      14      0       0     0            3           0
# 5                0       0      0       0     0            0           0
# 7                0       1      0       0     0            0           0
# 9                0       3      0       0     0            0           0
# 12               0       0      2       0     0            2           0
# ...            ...     ...    ...     ...   ...          ...         ...
# 5601             0       7      0       0     0            3           0
# 5610             0       0      0       0     0            0           0
# 5615             0       0      0       0     0            0           0
# 5616             0      17      0       0     0            1           0
# 5618             0       0      0       0     0            1           0
#
# [1529 rows x 17 columns]

# %%
art_df['predicted'] = art_df[sections_to_keep].apply(get_argmax, axis=1)

# %%
art_df
# Out:
#                      id sections  \
# 4     01/22/1820684.xml   Sports
# 5     01/22/1820655.xml     Arts
# 7     01/22/1820683.xml    World
# 9     01/22/1820743.xml   Sports
# 12    01/22/1820744.xml     U.S.
# ...                 ...      ...
# 5601  01/18/1819730.xml   Sports
# 5610  01/18/1819595.xml     Arts
# 5615  01/18/1819592.xml     Arts
# 5616  01/18/1819745.xml   Sports
# 5618  01/18/1819613.xml     U.S.
#
#                                                text_raw  num_sections  \
# 4     Marquette point guard Dominic James wore dark ...             1
# 5     Even in their absence, the Grateful Dead can p...             1
# 7     A damaged and listing cargo ship was spilling ...             1
# 9     As Chicago Bears defensive end Adewale Ogunley...             1
# 12    Nine years after he began serving a life sente...             1
# ...                                                 ...           ...
# 5601  The telephone calls keep coming, so Mets Gener...             1
# 5610  Stravinsky was arguably the most important com...             1
# 5615  When is bridge like poker? When bluffing is in...             1
# 5616  Casey Powell made a big mistake bringing his w...             1
# 5618  A Mexican immigrant was shot and killed on Fri...             1
#
#       sec_num                                               text  \
# 4           0  marquette point guard dominic james wore dark ...
# 5           1  even absence grateful dead pack hall saturday ...
# 7           3  damaged listing cargo ship spilling fuel cargo...
# 9           0  chicago bears defensive end adewale ogunleye w...
# 12          2  nine years began serving life sentence unabomb...
# ...       ...                                                ...
# 5601        0  telephone calls keep coming mets general manag...
# 5610        1  stravinsky arguably important composer dance 2...
# 5615        1  bridge like poker? bluffing involved poker per...
# 5616        0  casey powell made big mistake bringing wife ne...
# 5618        2  mexican immigrant shot killed friday border pa...
#
#                                             text_tokens  U.S.  World  Arts  \
# 4     [marquette, point, guard, dominic, james, wore...     0      1     0
# 5     [even, absence, grateful, dead, pack, hall, sa...     0      1     2
# 7     [damaged, listing, cargo, ship, spilling, fuel...     0      5     0
# 9     [chicago, bears, defensive, end, adewale, ogun...     0      0     0
# 12    [nine, years, began, serving, life, sentence, ...    11     11     0
# ...                                                 ...   ...    ...   ...
# 5601  [telephone, calls, keep, coming, mets, general...     0      1     0
# 5610  [stravinsky, arguably, important, composer, da...     1      0     3
# 5615  [bridge, like, poker?, bluffing, involved, pok...     0      0     0
# 5616  [casey, powell, made, big, mistake, bringing, ...     1      0     0
# 5618  [mexican, immigrant, shot, killed, friday, bor...     2      2     0
#
#       Business Day  Sports  Books  Movies  Food  Real Estate  Technology  \
# 4                0      14      0       0     0            3           0
# 5                0       0      0       0     0            0           0
# 7                0       1      0       0     0            0           0
# 9                0       3      0       0     0            0           0
# 12               0       0      2       0     0            2           0
# ...            ...     ...    ...     ...   ...          ...         ...
# 5601             0       7      0       0     0            3           0
# 5610             0       0      0       0     0            0           0
# 5615             0       0      0       0     0            0           0
# 5616             0      17      0       0     0            1           0
# 5618             0       0      0       0     0            1           0
#
#      predicted
# 4       Sports
# 5         Arts
# 7        World
# 9       Sports
# 12        U.S.
# ...        ...
# 5601    Sports
# 5610      Arts
# 5615      None
# 5616    Sports
# 5618      U.S.
#
# [1529 rows x 18 columns]

# %%
predict_df = art_df[~pd.isna(art_df['predicted'])].copy()

# %%
predict_df
# Out:
#                      id sections  \
# 4     01/22/1820684.xml   Sports
# 5     01/22/1820655.xml     Arts
# 7     01/22/1820683.xml    World
# 9     01/22/1820743.xml   Sports
# 12    01/22/1820744.xml     U.S.
# ...                 ...      ...
# 5600  01/18/1819742.xml   Sports
# 5601  01/18/1819730.xml   Sports
# 5610  01/18/1819595.xml     Arts
# 5616  01/18/1819745.xml   Sports
# 5618  01/18/1819613.xml     U.S.
#
#                                                text_raw  num_sections  \
# 4     Marquette point guard Dominic James wore dark ...             1
# 5     Even in their absence, the Grateful Dead can p...             1
# 7     A damaged and listing cargo ship was spilling ...             1
# 9     As Chicago Bears defensive end Adewale Ogunley...             1
# 12    Nine years after he began serving a life sente...             1
# ...                                                 ...           ...
# 5600  It is halfway through the season, and just the...             1
# 5601  The telephone calls keep coming, so Mets Gener...             1
# 5610  Stravinsky was arguably the most important com...             1
# 5616  Casey Powell made a big mistake bringing his w...             1
# 5618  A Mexican immigrant was shot and killed on Fri...             1
#
#       sec_num                                               text  \
# 4           0  marquette point guard dominic james wore dark ...
# 5           1  even absence grateful dead pack hall saturday ...
# 7           3  damaged listing cargo ship spilling fuel cargo...
# 9           0  chicago bears defensive end adewale ogunleye w...
# 12          2  nine years began serving life sentence unabomb...
# ...       ...                                                ...
# 5600        0  halfway season right time struggling team rein...
# 5601        0  telephone calls keep coming mets general manag...
# 5610        1  stravinsky arguably important composer dance 2...
# 5616        0  casey powell made big mistake bringing wife ne...
# 5618        2  mexican immigrant shot killed friday border pa...
#
#                                             text_tokens  U.S.  World  Arts  \
# 4     [marquette, point, guard, dominic, james, wore...     0      1     0
# 5     [even, absence, grateful, dead, pack, hall, sa...     0      1     2
# 7     [damaged, listing, cargo, ship, spilling, fuel...     0      5     0
# 9     [chicago, bears, defensive, end, adewale, ogun...     0      0     0
# 12    [nine, years, began, serving, life, sentence, ...    11     11     0
# ...                                                 ...   ...    ...   ...
# 5600  [halfway, season, right, time, struggling, tea...     2      0     0
# 5601  [telephone, calls, keep, coming, mets, general...     0      1     0
# 5610  [stravinsky, arguably, important, composer, da...     1      0     3
# 5616  [casey, powell, made, big, mistake, bringing, ...     1      0     0
# 5618  [mexican, immigrant, shot, killed, friday, bor...     2      2     0
#
#       Business Day  Sports  Books  Movies  Food  Real Estate  Technology  \
# 4                0      14      0       0     0            3           0
# 5                0       0      0       0     0            0           0
# 7                0       1      0       0     0            0           0
# 9                0       3      0       0     0            0           0
# 12               0       0      2       0     0            2           0
# ...            ...     ...    ...     ...   ...          ...         ...
# 5600             0       7      0       0     0            0           0
# 5601             0       7      0       0     0            3           0
# 5610             0       0      0       0     0            0           0
# 5616             0      17      0       0     0            1           0
# 5618             0       0      0       0     0            1           0
#
#      predicted
# 4       Sports
# 5         Arts
# 7        World
# 9       Sports
# 12        U.S.
# ...        ...
# 5600    Sports
# 5601    Sports
# 5610      Arts
# 5616    Sports
# 5618      U.S.
#
# [1397 rows x 18 columns]

# %%
predict_df['correct'] = predict_df['sections'] == predict_df['predicted']

# %%
correct_counts = predict_df['correct'].value_counts()

# %%
correct_counts
# Out:
# True     1060
# False     337
# Name: correct, dtype: int64

# %%
correct_counts[True] / (correct_counts[True]+correct_counts[False])
# Out:
# 0.7587687902648532

# %%
pd.crosstab(predict_df['correct'], predict_df['sections'], normalize="columns")
# Out:
# sections      Arts  Real Estate    Sports      U.S.     World
# correct
# False     0.321937     0.133333  0.038986  0.561702  0.278027
# True      0.678063     0.866667  0.961014  0.438298  0.721973
